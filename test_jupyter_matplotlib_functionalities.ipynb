# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from textwrap import wrap

# draw time series given a univariate normal distribution and a discrete uniform distribution
ts = pd.Series(data=np.random.randn(100), dtype='double')
ts2 = pd.Series(data=np.random.randint(-2,3,100))

fig = plt.figure(figsize=(8,4), dpi=90, facecolor='w', edgecolor='w')
fig.suptitle("Time Series", fontsize=16,y=1.1)
ax, ax2 = fig.subplots(1, 2, sharey=False)
ax.set_title("\n".join(wrap("Times Series: univariate normal distribution", 20)))
ax2.set_title("discrete uniform distribution")
# in this case, we are plotting the 2 time series in a different subplot
ax.plot(ts, color=[0.0, 1.0, 0.0])
ax2.plot(ts2, color=[0.0, 0.0, 0.1])

ax.set_xlabel('time (s)',fontsize='20')
ax.set_ylabel('value', fontsize='20')
ax.xaxis.label.set_color('red')
ax.yaxis.label.set_color('red')
ax.tick_params(axis='x', colors='blue')
ax.tick_params(axis='y', colors='blue')
ax.spines['bottom'].set_color('blue')
ax.spines['top'].set_color('blue')
ax.spines['right'].set_color('blue')

# %% [markdown]
# * Above draws on the same plot time series given a univariate normal distribution and a discrete uniform distribution
